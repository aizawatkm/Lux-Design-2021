# %% [markdown]
# <a href="https://colab.research.google.com/github/aizawatkm/Lux-Design-2021/blob/master/section_1/01_stock_price.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 株価の取得

# %%
# 1. ライブラリのインストール（yfinanceがインストールされていない場合はコメントを外してください）
#!pip install yfinance

# 2. ライブラリのインポート
import yfinance as yf

# 3. データの取得
# 例: トヨタ自動車 (証券コード: 7203)
# 日本株は証券コードの末尾に ".T" をつけるのがルールです
data = yf.download("7203.T", period="1mo", auto_adjust=True) # 過去1ヶ月分

# 4. データの表示
data
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price        Close    High     Low    Open    Volume
# Ticker      7203.T  7203.T  7203.T  7203.T    7203.T
# Date
# 2025-10-27  3218.0  3218.0  3165.0  3170.0  24626500
# 2025-10-28  3171.0  3221.0  3167.0  3220.0  19805700
# 2025-10-29  3146.0  3182.0  3124.0  3176.0  20640200
# 2025-10-30  3185.0  3190.0  3125.0  3148.0  23926200
# 2025-10-31  3138.0  3198.0  3121.0  3190.0  25906600
# 2025-11-04  3155.0  3205.0  3120.0  3150.0  26958800
# 2025-11-05  3040.0  3151.0  2996.0  3150.0  56932600
# 2025-11-06  3139.0  3182.0  3054.0  3110.0  32756900
# 2025-11-07  3118.0  3128.0  3077.0  3090.0  17774800
# 2025-11-10  3131.0  3134.0  3090.0  3133.0  19709600
# 2025-11-11  3147.0  3177.0  3129.0  3148.0  17570500
# 2025-11-12  3190.0  3214.0  3175.0  3176.0  20882100
# 2025-11-13  3198.0  3215.0  3180.0  3200.0  16407400
# 2025-11-14  3180.0  3180.0  3134.0  3155.0  17302600
# 2025-11-17  3119.0  3164.0  3114.0  3150.0  15668000
# 2025-11-18  3029.0  3114.0  3028.0  3106.0  21663600
# 2025-11-19  3037.0  3075.0  3019.0  3074.0  15126800
# 2025-11-20  3044.0  3103.0  3044.0  3095.0  17872000
# 2025-11-21  3097.0  3120.0  3028.0  3035.0  31305500
# 2025-11-25  3077.0  3150.0  3070.0  3150.0  17998000
# 2025-11-26  3141.0  3158.0  3090.0  3129.0  20618800

# %% [markdown]
# # 株式の情報

# %%
# 1. Tickerオブジェクトを作成（ここではトヨタ自動車: 7203.T）
ticker = yf.Ticker("7203.T")

# 2. 情報を取得 (.info に辞書形式で入っています)
info = ticker.info
info

# %% [markdown]
# 情報を個別に取得することもできます。

# %%
print(f"【時価総額】 {info.get('marketCap'):,} 円")
print(f"【PER (株価収益率)】 {info.get('trailingPE')}")
print(f"【PBR (株価純資産倍率)】 {info.get('priceToBook')}")
print(f"【配当利回り】 {info.get('dividendYield', 0) * 100:.2f} %")

# %% [markdown]
# # 財務データ

# %% [markdown]
# 損益計算書

# %%
ticker.income_stmt

# %% [markdown]
# バランスシート

# %%
ticker.balance_sheet

# %% [markdown]
# キャッシュフロー

# %%
ticker.cashflow

# %% [markdown]
# # 銘柄の関連ニュース

# %%
ticker.news
